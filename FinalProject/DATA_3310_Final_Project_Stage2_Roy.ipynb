# %% [markdown]
# # Final Project Introduction and Brainstorming: Energy and Environment
# Team Members: Zoe Jackson, Roy Pan, Aspen Scott-Lewis, Michael Williams

# %% [markdown]
# ## **Step 1: Deciding on Data Sources**
#
# As a group, decide on a theme (or related themes) that you want to explore as your final project topic. It should be a topic that is of relevance to you (e.g. a hobby you are very passionate about) or the world (e.g. climate change, food insecurity). Ideally, your topic should surround a modern local, national or global issue. Determine a handful of datasets that could be more rich when considered together. A good start would be to choose a "core" dataset and then finding 1-2 supporting sources. If you have an idea for a topic but can't find supporting data, ask Dr. Mendible for help!
#
# Individually, each group member should download and investigate one unique data set. Answer the following questions about each one:
#
# What is available in this data set? What are the variables (either a complete list or a summary of the theme)? How many observations are included?
# Are there any challenges with this data set? Does it need to be cleaned, manipulated, or reshaped to be useful? Are these manipulations straightforward or will they take longer?
# How will this data be merged or used with the rest of the data?
# Then, share in your groups what you found. Make a team decision on what data you will be using for the final project.

# %%
# !pip install vega_datasets
# !pip install pycountry
# !pip install pycountry_convert

# %%
import pandas as pd
import altair as alt
from vega_datasets import data as vega_data
import pycountry
import pycountry_convert

import os
import requests

# %%
def load_remote_file_if_not_exists(filename: str, url: str) -> None:
  if not os.path.exists(filename):
    resp = requests.get(url)
    with open(filename, "wb") as f:
      f.write(resp.content)

# %% [markdown]
# Roy Pan
#
# Dataset: [Energy consumption by source and country](https://ourworldindata.org/grapher/energy-consumption-by-source-and-country)
#
# As its name suggets, it contains different countries for different years for several energy sources (e.g. Solar, Wind, Hydropower, Nuclear, Gas, Coal, Oil). While it contains many data, it doesn't include every country (and some of them on there is blank), so the challenges have been to map the missing ones to a default value like the continent they're on.

# %%
# For Visualization 3
energy_consumption_by_source_and_country_filename = "energy-consumption-by-source-and-country.csv"
load_remote_file_if_not_exists(energy_consumption_by_source_and_country_filename, "https://raw.githubusercontent.com/roy-y-2023/data3310/refs/heads/main/data/energy-consumption-by-source-and-country.csv")
energy_consumption_by_source_and_country_df = pd.read_csv(energy_consumption_by_source_and_country_filename)
energy_consumption_by_source_and_country_df.head()
# Out:
#    Entity Code  Year  Other renewables  Biofuels  Solar  Wind  Hydropower  \
# 0  Africa  NaN  1965               0.0       0.0    0.0   0.0   38.626762
# 1  Africa  NaN  1966               0.0       0.0    0.0   0.0   43.083344
# 2  Africa  NaN  1967               0.0       0.0    0.0   0.0   44.973988
# 3  Africa  NaN  1968               0.0       0.0    0.0   0.0   52.606503
# 4  Africa  NaN  1969               0.0       0.0    0.0   0.0   61.391357
#
#    Nuclear        Gas       Coal        Oil
# 0      0.0   9.571930  323.49615  341.07257
# 1      0.0  10.698092  323.12222  369.46457
# 2      0.0  10.573844  330.29160  368.28156
# 3      0.0  10.717145  343.51288  389.57162
# 4      0.0  12.520175  346.64288  397.37260

# %%
CLEAN_ENERGY_SOURCE_NAMES = ["Other renewables", "Biofuels", "Solar", "Wind", "Hydropower", "Nuclear"]
energy_consumption_by_source_and_country_df["Total_Conventional_Energy"] = energy_consumption_by_source_and_country_df["Gas"] + energy_consumption_by_source_and_country_df["Coal"] + energy_consumption_by_source_and_country_df["Oil"]
energy_consumption_by_source_and_country_df["Total_Clean_Energy"] = energy_consumption_by_source_and_country_df["Other renewables"] + energy_consumption_by_source_and_country_df["Biofuels"] + energy_consumption_by_source_and_country_df["Solar"] + energy_consumption_by_source_and_country_df["Wind"] + energy_consumption_by_source_and_country_df["Hydropower"] + energy_consumption_by_source_and_country_df["Nuclear"]
energy_consumption_by_source_and_country_df["Total"] = energy_consumption_by_source_and_country_df["Total_Conventional_Energy"] + energy_consumption_by_source_and_country_df["Total_Clean_Energy"]
energy_consumption_by_source_and_country_df["Clean_Energy_Share"] = energy_consumption_by_source_and_country_df["Total_Clean_Energy"] / energy_consumption_by_source_and_country_df["Total"] * 100
energy_consumption_by_source_and_country_df_2024 = energy_consumption_by_source_and_country_df[energy_consumption_by_source_and_country_df["Year"] == 2024]

energy_consumption_by_source_and_country_df_valid = energy_consumption_by_source_and_country_df_2024.dropna(subset=["Clean_Energy_Share"])
code_to_share = energy_consumption_by_source_and_country_df_valid.set_index("Code")["Clean_Energy_Share"].to_dict()
code_to_entity = energy_consumption_by_source_and_country_df_valid.set_index("Code")["Entity"].to_dict()
entity_to_share = energy_consumption_by_source_and_country_df.set_index("Entity")["Clean_Energy_Share"].to_dict()

def get_continent_share(alpha_2: str) -> float | None:
    try:
        continent_code = pycountry_convert.country_alpha2_to_continent_code(alpha_2)
        continent_name = pycountry_convert.convert_continent_code_to_continent_name(continent_code)
        return entity_to_share.get(continent_name) if continent_name else None
    except Exception:
        return 0

rows = []
for country in pycountry.countries:
    alpha_3 = country.alpha_3
    alpha_2 = country.alpha_2

    if alpha_3 in code_to_share:
        entity = code_to_entity[alpha_3]
        share = code_to_share[alpha_3]
    else:
        entity = country.name
        share = get_continent_share(alpha_2)

    rows.append({"Entity": entity, "Code_Num": int(country.numeric), "Clean_Energy_Share": share})

all_countries_energy_consumption_by_source_df = pd.DataFrame(rows)
all_countries_energy_consumption_by_source_df = all_countries_energy_consumption_by_source_df[all_countries_energy_consumption_by_source_df["Entity"] != "Antarctica"]
all_countries_energy_consumption_by_source_df.head()
# Out:
#           Entity  Code_Num  Clean_Energy_Share
# 0          Aruba       533           20.261376
# 1    Afghanistan         4           15.011216
# 2         Angola        24            9.665484
# 3       Anguilla       660           20.261376
# 4  Åland Islands       248           26.247755

# %% [markdown]
# ## **Step 2: Visualization Brainstorming**
#
# Then as a group, brainstorm a list of at least 5 visualizations that could be made with this collective information. Come up with a one-sentence statement or question that the graphic would address. For each of the visualizations, answer the following questions. Your answer can be in the form of a mock-up if you have ready-to-plot data.
#
# What variables would you use to show this?
# Do you need to compute new variables, filter, or do other manipulations to show this?
# What chart type (line, scatter, bar, etc) would be most effective to show this?
# Which encodings would you map to which variables?
# What other design considerations (color, scales, titles, labels, ticks) would you need to make? If you don't know yet, that's ok, but give a best guess.
# Compile your answers into a single notebook and submit it here.

# %%
dfASL = pd.read_csv('https://raw.githubusercontent.com/AspenSL04/Data3310/refs/heads/main/consolidated-edata-sheets.csv')
c1 = alt.Chart(dfASL).mark_bar().encode(
    alt.X('2014-24 renew gen growth', title='% Renewable Energy Generation Growth 2014-2024').axis(format='.0%'),
    alt.Y('Terawatt-hours renew gen', title='Country').sort('-x')
).transform_window(
    rank='rank(2014-24 renew gen growth)',
sort=[alt.SortField('2014-24 renew gen growth', order='descending')]
).transform_filter(
    (alt.datum.rank < 20)
)

c2 = alt.Chart(dfASL).mark_bar().encode(
    alt.X('Total source 24 growth', title = '% Growth in Renewable Energy Sources in 2024').axis(format='.0%'),
    alt.Y('Terawatt-hours source 23', title='Country').sort('-x')
).transform_window(
    rank='rank(Total source 24 growth)',
sort=[alt.SortField('Total source 24 growth', order='descending')]
).transform_filter(
    (alt.datum.rank < 20)
)

c1 | c2
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# These two charts show the top twenty countries growing their renewable energy generation and renewable energy sources. These were quick to plot but other charts showing data not already provided by the dataset will require more processing. They also reveal that the dataset includes some grouped entities (such as Other Southern Africa) that will need processing to show seperately or exclude
# -Aspen

# %% [markdown]
# Visualization 3:
#
# I'm using the share of clean energy for a given country as percentage, computed from the raw values, that's neccessary for showing on Choropleths and other types of charts in general as different country have different baseline that will cause many smaller countries to have nearly zero.
#
# Alternatively it can be shown as bar chart. Although the Choropleths chart isn't good at showing precise values, but it does show off geographical relationship of these values, that countries next to each other might have similar share of clean energy, and some regions have high share of clean energy.
#
# One sentence statement: North Europe has the highest share of energy being clean energy, while Africa in general has the lowest.

# %%
countries = alt.topo_feature(vega_data.world_110m.url, 'countries')

alt.Chart(countries).mark_geoshape().encode(
    alt.Color("Clean_Energy_Share:Q", bin=alt.Bin(maxbins=10)),
    tooltip='Entity:N'
).transform_lookup(
    lookup='id',
    from_=alt.LookupData(all_countries_energy_consumption_by_source_df, 'Code_Num', ["Clean_Energy_Share", "Entity"])
).project(
    "naturalEarth1"
).properties(
    title='Share of Clean Energy (2024)',
    width=800,
    height=500
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Stage 2

# %% [markdown]
# ### Which clean energy grows the fastest?

# %%
world_energy_consumption_by_source_df = energy_consumption_by_source_and_country_df[energy_consumption_by_source_and_country_df["Entity"] == "World"]
world_energy_consumption_by_source_df
# Out:
#      Entity      Code  Year  Other renewables     Biofuels        Solar  \
# 8143  World  OWID_WRL  1965         56.203850     9.029861     0.000000
# 8144  World  OWID_WRL  1966         61.893772     9.209844     0.000000
# 8145  World  OWID_WRL  1967         62.458030     9.383716     0.000000
# 8146  World  OWID_WRL  1968         69.125140     9.553800     0.000000
# 8147  World  OWID_WRL  1969         72.681140     9.723982     0.000000
# 8148  World  OWID_WRL  1970         80.318430    13.501495     0.000000
# 8149  World  OWID_WRL  1971         87.150920    13.562147     0.000000
# 8150  World  OWID_WRL  1972         93.402420    14.823111     0.000000
# 8151  World  OWID_WRL  1973        100.299540    14.250557     0.000000
# 8152  World  OWID_WRL  1974        107.153390    14.334716     0.000000
# 8153  World  OWID_WRL  1975        108.787750    13.688392     0.000000
# 8154  World  OWID_WRL  1976        121.222030    13.751190     0.000000
# 8155  World  OWID_WRL  1977        127.787630    18.318535     0.000000
# 8156  World  OWID_WRL  1978        135.302030    23.178776     0.000000
# 8157  World  OWID_WRL  1979        145.310180    28.023214     0.000000
# 8158  World  OWID_WRL  1980        155.367080    32.786120     0.000000
# 8159  World  OWID_WRL  1981        167.144290    29.747923     0.000000
# 8160  World  OWID_WRL  1982        192.840480    37.556244     0.000000
# 8161  World  OWID_WRL  1983        213.609150    49.019240     0.008333
# 8162  World  OWID_WRL  1984        238.581730    57.806427     0.017531
# 8163  World  OWID_WRL  1985        245.945560    68.410095     0.032632
# 8164  World  OWID_WRL  1986        267.010560    84.202995     0.042177
# 8165  World  OWID_WRL  1987        285.987580    85.330120     0.029453
# 8166  World  OWID_WRL  1988        294.252840    89.560200     0.028322
# 8167  World  OWID_WRL  1989        327.101140    95.689240     0.728398
# 8168  World  OWID_WRL  1990        366.326080   106.569110     1.078472
# 8169  World  OWID_WRL  1991        382.072500   110.646830     1.403397
# 8170  World  OWID_WRL  1992        409.874730   108.705635     1.296053
# 8171  World  OWID_WRL  1993        423.377660   114.340060     1.546326
# 8172  World  OWID_WRL  1994        439.616970   124.101776     1.658286
# 8173  World  OWID_WRL  1995        458.257400   131.070400     1.774674
# 8174  World  OWID_WRL  1996        470.949070   125.784515     1.942305
# 8175  World  OWID_WRL  1997        504.411650   130.030650     2.082377
# 8176  World  OWID_WRL  1998        525.679400   133.383960     2.255144
# 8177  World  OWID_WRL  1999        552.025200   135.247360     2.514689
# 8178  World  OWID_WRL  2000        577.878200   132.508770     2.939253
# 8179  World  OWID_WRL  2001        600.235400   131.424940     3.928208
# 8180  World  OWID_WRL  2002        646.155600   149.314600     4.923327
# 8181  World  OWID_WRL  2003        682.598630   168.931660     6.137612
# 8182  World  OWID_WRL  2004        737.757000   201.200490     8.043655
# 8183  World  OWID_WRL  2005        798.361270   234.475200    11.242224
# 8184  World  OWID_WRL  2006        850.215500   294.601960    15.387916
# 8185  World  OWID_WRL  2007        922.815100   391.652200    20.759594
# 8186  World  OWID_WRL  2008        987.290300   535.942140    33.458040
# 8187  World  OWID_WRL  2009       1056.993700   600.635500    55.273674
# 8188  World  OWID_WRL  2010       1182.440800   678.900760    88.336430
# 8189  World  OWID_WRL  2011       1240.742900   717.312100   170.319930
# 8190  World  OWID_WRL  2012       1339.847900   746.395140   261.639100
# 8191  World  OWID_WRL  2013       1441.806400   818.510440   354.499940
# 8192  World  OWID_WRL  2014       1569.092200   865.945600   502.021480
# 8193  World  OWID_WRL  2015       1669.679100   898.433170   649.451900
# 8194  World  OWID_WRL  2016       1709.845300   938.653260   824.157700
# 8195  World  OWID_WRL  2017       1800.717800   957.890870  1114.711300
# 8196  World  OWID_WRL  2018       1952.103800  1038.815400  1431.774800
# 8197  World  OWID_WRL  2019       2038.120200  1127.313600  1748.829300
# 8198  World  OWID_WRL  2020       2152.289800  1068.229600  2116.744100
# 8199  World  OWID_WRL  2021       2317.554200  1128.119400  2593.081300
# 8200  World  OWID_WRL  2022       2379.479500  1193.131200  3249.745600
# 8201  World  OWID_WRL  2023       2411.358400  1319.216300  4026.581800
# 8202  World  OWID_WRL  2024       2476.356700  1366.878300  5150.569300
#
#              Wind  Hydropower      Nuclear         Gas       Coal        Oil  \
# 8143     0.000000   2564.4390    70.943670   6303.8210  16177.694  18011.457
# 8144     0.000000   2732.8247    95.648020   6868.8145  16359.431  19426.414
# 8145     0.000000   2793.7288   113.905594   7374.0580  16095.518  20778.916
# 8146     0.000000   2942.4685   144.758770   8044.3477  16333.144  22510.490
# 8147     0.000000   3115.9512   171.620590   8833.4340  16847.000  24445.395
# 8148     0.000000   3262.9155   219.096250   9614.8090  17087.006  26684.725
# 8149     0.000000   3409.0059   304.733830  10293.1900  16987.656  28116.584
# 8150     0.000000   3568.4138   422.708740  10861.7140  17168.227  30335.396
# 8151     0.000000   3619.4802   566.393250  11377.8330  17683.570  32730.184
# 8152     0.000000   3975.6433   740.555800  11659.8590  17696.432  32230.395
# 8153     0.000000   4024.6760  1027.356100  11659.7360  18045.436  31996.514
# 8154     0.000000   4008.7126  1201.865000  12354.1390  18699.785  34061.470
# 8155     0.000000   4143.5340  1495.966100  12759.8380  19267.412  35194.340
# 8156     0.008333   4484.3950  1738.317600  13293.9470  19467.492  36709.973
# 8157     0.016667   4708.8500  1807.944200  14118.0290  20370.578  37177.996
# 8158     0.029167   4810.1367  1977.567100  14236.9610  20877.783  35568.645
# 8159     0.029167   4913.6206  2335.418700  14395.8740  21158.002  34289.960
# 8160     0.051389   5002.5225  2533.826400  14469.7310  21395.428  33270.010
# 8161     0.091097   5216.0244  2871.702000  14703.8270  22050.973  33097.430
# 8162     0.124321   5392.7036  3484.912400  15902.6760  23008.440  33623.600
# 8163     0.178389   5497.8990  4135.893000  16262.2180  23996.738  33684.684
# 8164     0.385643   5572.4250  4429.821300  16421.1070  24263.818  34710.477
# 8165     0.542713   5647.7563  4818.703000  17281.8930  25228.488  35508.195
# 8166     0.921055   5828.7466  5253.470000  18088.8440  25983.080  36641.938
# 8167     7.360490   5798.8525  5402.807000  18888.6480  26231.049  37215.688
# 8168    10.090196   5996.1724  5557.211000  19481.1500  25928.912  37906.816
# 8169    11.350296   6134.8447  5823.082500  19972.8380  25686.727  37876.832
# 8170    13.146699   6134.2070  5867.285600  20063.4820  25584.300  38404.773
# 8171    15.844913   6503.6680  6069.345700  20265.4820  25708.832  38246.242
# 8172    19.810360   6544.1816  6183.274000  20389.6130  25815.188  39068.176
# 8173    22.978119   6898.3022  6451.471000  21104.4920  25999.217  39666.370
# 8174    25.598890   6991.1523  6685.041500  22159.2540  26617.482  40576.630
# 8175    33.411713   7114.8765  6639.067000  22030.3930  26563.252  41652.086
# 8176    44.247944   7169.2590  6753.319000  22434.0000  26395.965  41788.617
# 8177    58.963604   7223.5240  7010.293000  23071.9040  26508.807  42435.785
# 8178    87.248740   7351.8926  7168.520500  23994.2580  27456.373  43016.630
# 8179   106.022120   7123.2290  7330.212000  24316.8320  27880.072  43398.320
# 8180   143.511750   7194.9185  7386.150000  25051.9280  28982.217  43697.090
# 8181   172.437620   7146.9575  7197.058600  25727.7340  31519.594  44610.883
# 8182   232.028170   7632.8750  7483.358400  26781.6200  33708.973  46413.184
# 8183   281.256070   7825.9550  7442.488000  27439.2250  36200.953  47016.887
# 8184   356.959400   8080.8350  7494.947800  28171.7090  38087.040  47436.953
# 8185   456.129240   8171.3030  7303.106000  29338.2850  40241.703  48087.520
# 8186   584.201660   8579.4010  7222.835000  30050.7460  40796.645  47692.652
# 8187   726.502140   8520.5610  7083.252000  29403.6050  40219.008  46633.970
# 8188   902.106930   8932.5850  7209.022500  31592.8710  42016.016  48192.543
# 8189  1142.296600   9048.1250  6871.570300  32349.8850  43983.350  48578.273
# 8190  1368.069200   9385.1390  6367.377400  33246.4380  44098.684  49362.210
# 8191  1626.221000   9687.9640  6368.981000  33733.2660  44745.465  49922.812
# 8192  1797.047200   9895.8580  6465.966300  33976.3550  44912.370  50336.395
# 8193  2105.701200   9820.6720  6519.849600  34780.0430  43695.344  51294.030
# 8194  2418.754600  10090.3380  6566.975600  35583.9840  42767.824  52314.516
# 8195  2856.328400  10171.0450  6592.505000  36603.0550  43226.340  53263.332
# 8196  3162.158700  10419.3920  6716.976000  38317.0600  43897.330  53792.790
# 8197  3520.443800  10501.5490  6920.192400  39053.1800  43627.613  53997.266
# 8198  3940.164600  10763.2800  6639.518000  38704.0470  42316.324  49101.246
# 8199  4582.781200  10575.5320  6903.326700  40225.7340  44642.164  51846.820
# 8200  5184.601600  10650.5950  6583.330600  40059.6520  44926.926  53562.110
# 8201  5665.208000  10392.0800  6677.130000  40151.2200  45319.086  54838.684
# 8202  6124.465300  10860.7530  6871.835000  41278.2700  45850.543  55292.082
#
#       Total_Conventional_Energy  Total_Clean_Energy          Total  \
# 8143                 40492.9720         2700.616381   43193.588381
# 8144                 42654.6595         2899.576336   45554.235836
# 8145                 44248.4920         2979.476140   47227.968140
# 8146                 46887.9817         3165.906210   50053.887910
# 8147                 50125.8290         3369.976912   53495.805912
# 8148                 53386.5400         3575.831675   56962.371675
# 8149                 55397.4300         3814.452797   59211.882797
# 8150                 58365.3370         4099.348071   62464.685071
# 8151                 61791.5870         4300.423547   66092.010547
# 8152                 61586.6860         4837.687206   66424.373206
# 8153                 61701.6860         5174.508242   66876.194242
# 8154                 65115.3940         5345.550820   70460.944820
# 8155                 67221.5900         5785.606265   73007.196265
# 8156                 69471.4120         6381.201739   75852.613739
# 8157                 71666.6030         6690.144261   78356.747261
# 8158                 70683.3890         6975.886167   77659.275167
# 8159                 69843.8360         7445.960680   77289.796680
# 8160                 69135.1690         7766.797013   76901.966013
# 8161                 69852.2300         8350.454220   78202.684220
# 8162                 72534.7160         9174.146009   81708.862009
# 8163                 73943.6400         9948.358676   83891.998676
# 8164                 75395.4020        10353.887675   85749.289675
# 8165                 78018.5760        10838.349166   88856.925166
# 8166                 80713.8620        11466.979017   92180.841017
# 8167                 82335.3850        11632.538768   93967.923768
# 8168                 83316.8780        12037.447258   95354.325258
# 8169                 83536.3970        12463.400223   95999.797223
# 8170                 84052.5550        12534.515717   96587.070717
# 8171                 84220.5560        13128.122659   97348.678659
# 8172                 85272.9770        13312.642992   98585.619992
# 8173                 86770.0790        13963.853793  100733.932793
# 8174                 89353.3660        14300.468580  103653.834580
# 8175                 90245.7310        14423.879890  104669.610890
# 8176                 90618.5820        14628.144448  105246.726448
# 8177                 92016.4960        14982.567853  106999.063852
# 8178                 94467.2610        15320.988063  109788.249063
# 8179                 95595.2240        15295.051668  110890.275668
# 8180                 97731.2350        15524.973777  113256.208777
# 8181                101858.2110        15374.121622  117232.332622
# 8182                106903.7770        16295.262715  123199.039715
# 8183                110657.0650        16593.777764  127250.842764
# 8184                113695.7020        17092.947576  130788.649576
# 8185                117667.5080        17265.765134  134933.273134
# 8186                118540.0430        17943.128140  136483.171140
# 8187                116256.5830        18043.218014  134299.801014
# 8188                121801.4300        18993.392420  140794.822420
# 8189                124911.5080        19190.366830  144101.874830
# 8190                126707.3320        19468.467740  146175.799740
# 8191                128401.5430        20297.982780  148699.525780
# 8192                129225.1200        21095.930780  150321.050780
# 8193                129769.4170        21663.786970  151433.203970
# 8194                130666.3240        22548.724460  153215.048460
# 8195                133092.7270        23493.198370  156585.925370
# 8196                136007.1800        24721.220700  160728.400700
# 8197                136678.0590        25856.448300  162534.507300
# 8198                130121.6170        26680.226100  156801.843100
# 8199                136714.7180        28100.394800  164815.112800
# 8200                138548.6880        29240.883500  167789.571500
# 8201                140308.9900        30491.574500  170800.564500
# 8202                142420.8950        32850.857600  175271.752600
#
#       Clean_Energy_Share
# 8143            6.252355
# 8144            6.365108
# 8145            6.308711
# 8146            6.324996
# 8147            6.299516
# 8148            6.277533
# 8149            6.442039
# 8150            6.562665
# 8151            6.506722
# 8152            7.283000
# 8153            7.737444
# 8154            7.586544
# 8155            7.924707
# 8156            8.412633
# 8157            8.538058
# 8158            8.982683
# 8159            9.633821
# 8160           10.099608
# 8161           10.677964
# 8162           11.227847
# 8163           11.858531
# 8164           12.074605
# 8165           12.197529
# 8166           12.439655
# 8167           12.379266
# 8168           12.623913
# 8169           12.982736
# 8170           12.977426
# 8171           13.485671
# 8172           13.503636
# 8173           13.862115
# 8174           13.796372
# 8175           13.780389
# 8176           13.898907
# 8177           14.002522
# 8178           13.955035
# 8179           13.792960
# 8180           13.707835
# 8181           13.114233
# 8182           13.226777
# 8183           13.040211
# 8184           13.069137
# 8185           12.795780
# 8186           13.146770
# 8187           13.435030
# 8188           13.490121
# 8189           13.317222
# 8190           13.318530
# 8191           13.650335
# 8192           14.033917
# 8193           14.305837
# 8194           14.717043
# 8195           15.003391
# 8196           15.380742
# 8197           15.908282
# 8198           17.015250
# 8199           17.049647
# 8200           17.427116
# 8201           17.852151
# 8202           18.742813

# %%
world_energy_consumption_by_source_and_year_df = world_energy_consumption_by_source_df.melt(
    id_vars=['Year'],
    value_vars=CLEAN_ENERGY_SOURCE_NAMES,
    var_name='Clean Energy Source',
    value_name='Energy Consumption'
)
world_energy_consumption_by_source_and_year_df
# Out:
#      Year Clean Energy Source  Energy Consumption
# 0    1965    Other renewables           56.203850
# 1    1966    Other renewables           61.893772
# 2    1967    Other renewables           62.458030
# 3    1968    Other renewables           69.125140
# 4    1969    Other renewables           72.681140
# ..    ...                 ...                 ...
# 355  2020             Nuclear         6639.518000
# 356  2021             Nuclear         6903.326700
# 357  2022             Nuclear         6583.330600
# 358  2023             Nuclear         6677.130000
# 359  2024             Nuclear         6871.835000
#
# [360 rows x 3 columns]

# %%
world_energy_consumption_by_source_and_year_df = world_energy_consumption_by_source_and_year_df.sort_values(['Clean Energy Source', 'Year'])
world_energy_consumption_by_source_and_year_df["Amount Chnage"] = world_energy_consumption_by_source_and_year_df.groupby("Clean Energy Source")["Energy Consumption"].diff()
world_energy_consumption_by_source_and_year_df["Percent Change"] = world_energy_consumption_by_source_and_year_df.groupby("Clean Energy Source")["Energy Consumption"].pct_change() * 100
# world_energy_consumption_by_source_and_year_df = world_energy_consumption_by_source_and_year_df.dropna()  # Remove NaN rows (first year of each group)
world_energy_consumption_by_source_and_year_df
# Out:
#      Year Clean Energy Source  Energy Consumption  Amount Chnage  \
# 60   1965            Biofuels            9.029861            NaN
# 61   1966            Biofuels            9.209844       0.179983
# 62   1967            Biofuels            9.383716       0.173872
# 63   1968            Biofuels            9.553800       0.170084
# 64   1969            Biofuels            9.723982       0.170182
# ..    ...                 ...                 ...            ...
# 235  2020                Wind         3940.164600     419.720800
# 236  2021                Wind         4582.781200     642.616600
# 237  2022                Wind         5184.601600     601.820400
# 238  2023                Wind         5665.208000     480.606400
# 239  2024                Wind         6124.465300     459.257300
#
#      Percent Change
# 60              NaN
# 61         1.993198
# 62         1.887893
# 63         1.812544
# 64         1.781302
# ..              ...
# 235       11.922383
# 236       16.309385
# 237       13.132209
# 238        9.269881
# 239        8.106627
#
# [360 rows x 5 columns]

# %%
world_energy_consumption_by_source_and_year_base = alt.Chart(world_energy_consumption_by_source_and_year_df).encode(
    x=alt.X("Year:O", title="Year"),
    y=alt.Y("Energy Consumption:Q", title="Energy Consumption (TWh)"),
    color=alt.Color("Clean Energy Source:N", title="Source", legend=alt.Legend(orient="right", offset=100))
)

world_energy_consumption_by_source_and_year_lines = world_energy_consumption_by_source_and_year_base.mark_line().encode(
    tooltip=["Year", "Clean Energy Source", "Energy Consumption"]
)
world_energy_consumption_by_source_and_year_labels = world_energy_consumption_by_source_and_year_base.mark_text(align="left", dx=5).encode(
    text="Clean Energy Source:N"
).transform_filter(
    alt.datum.Year == 2024
)

(world_energy_consumption_by_source_and_year_lines + world_energy_consumption_by_source_and_year_labels).properties(
    title="Global Clean Energy Consumption Over Time (1965-2024)",
    width=800,
    height=400,
    padding={"left": 5, "top": 5, "right": 120, "bottom": 5}
)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# Observations:
# - Hydropower has been and steady increase over the years
# - Nuclear reachs its peak arounf 2000 and staggering since then.
# - Wind and Solar is exponentially increasing in the past two decades.

# %%
change_of_world_energy_consumption_by_source_and_year_base = alt.Chart(world_energy_consumption_by_source_and_year_df).encode(
    x=alt.X('Year:O', title='Year'),
    y=alt.Y('Percent Change:Q', title='Year-over-Year Growth (%)', scale=alt.Scale(domain=[-20, 100], clamp=True)),
    color=alt.Color('Clean Energy Source:N', legend=alt.Legend(orient="right", offset=100))
)

change_of_world_energy_consumption_by_source_and_year_lines = change_of_world_energy_consumption_by_source_and_year_base.mark_line().encode(
    tooltip=['Year', 'Clean Energy Source', 'Percent Change']
)

change_of_world_energy_consumption_by_source_and_year_labels_right = change_of_world_energy_consumption_by_source_and_year_base.mark_text(align='left', dx=5).encode(
    text='Clean Energy Source:N'
).transform_filter(
    alt.datum.Year == 2024
)

(change_of_world_energy_consumption_by_source_and_year_lines + change_of_world_energy_consumption_by_source_and_year_labels_right).properties(
    title='Global Clean Energy Growth Rates (%)',
    width=800,
    height=400,
    padding={'left': 5, 'top': 5, 'right': 120, 'bottom': 5}
)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# - The changes for each energy source is rather wild
# - In recent year, solar and wind seems to be the clear winners in terms of increases.

# %% [markdown]
# ### Change of clean energy share vs. life expectancy

# %%
life_expectancy_filename = "life-expectancy.csv"
load_remote_file_if_not_exists(life_expectancy_filename, "https://github.com/roy-y-2023/data3310/raw/refs/heads/fix-map/FinalProject/life-expectancy.csv")
life_expectancy_df = pd.read_csv(life_expectancy_filename)
life_expectancy_df.head()
# Out:
#    Entity Code  Year  Life expectancy
# 0  Africa  NaN  1770          26.4000
# 1  Africa  NaN  1925          26.4000
# 2  Africa  NaN  1950          37.2455
# 3  Africa  NaN  1951          37.7751
# 4  Africa  NaN  1952          38.2546

# %%
continent_entity_names = set(life_expectancy_df["Entity"])
continent_entity_names
# Out:
# {'Africa', 'Americas', 'Asia', 'Europe', 'Oceania', 'World'}
